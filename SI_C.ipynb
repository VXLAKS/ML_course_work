# %%
# Импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from xgboost import XGBClassifier
from sklearn.ensemble import (RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, ExtraTreesClassifier)
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score, KFold, train_test_split, RandomizedSearchCV
import optuna

# %%
# Загружаем данные
data = pd.read_csv('data/si_data.csv')

# %% [markdown]
# Для выполнения задания необходимо создать бинарный столбец, который будет показывать, превышает ли значение SI медианное значение по выборке. Этот столбец станет целевой переменной для задачи классификации.

# %%
# Вычислим медиану по столбцу SI_log
si_median = data['SI_log'].median()

# Создаем бинарный столбец, показывающий, больше ли значение SI_log медианы
data['SI_log_binary'] = (data['SI_log'] > si_median).astype(int)

# Убираем переменную, на основе которой был создан бинарный целевой признак
data = data.drop(columns=['SI_log'])

# %% [markdown]
# Перед тем как приступить к дальнейшей работе, необходимо проверить баланс классов.

# %%
# Проверяем баланс классов
print(data['SI_log_binary'].value_counts())
print(data['SI_log_binary'].value_counts(normalize=True))
# Out:
# SI_log_binary
# 0    465
# 1    464
# Name: count, dtype: int64
# SI_log_binary
# 0    0.500538
# 1    0.499462
# Name: proportion, dtype: float64

# %% [markdown]
# Баланс классов почти идеальный — примерно 50/50, значит с дисбалансом проблем нет.

# %%
# Разделяем данные и убираем целевую переменную
X = data.drop(columns=['SI_log_binary'])
y = data['SI_log_binary']

# %%
# Разделение данных (70% тренировочные, 30% тестовые)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Тренировочные данные: {X_train.shape[0]}")
print(f"Тестовые данные: {X_test.shape[0]}")
# Out:
# Тренировочные данные: 650
# Тестовые данные: 279

# %%
# Инициализация моделей со стандартными параметрами
models = {
    'XGBoost': XGBClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'CatBoost': CatBoostClassifier(verbose=0, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'HistGradient Boosting': HistGradientBoostingClassifier(random_state=42, loss='log_loss'),
    'Extra Trees': ExtraTreesClassifier(random_state=42),
}

# %%
# Функция для оценки моделей
def evaluate_model(model, X_train, y_train, X_test, y_test):
    """Оценивает классификационную модель и возвращает accuracy и F1-score"""
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    return {
        'Accuracy': round(accuracy_score(y_test, y_pred), 4),
        'F1-score': round(f1_score(y_test, y_pred), 4),
        'Precision': round(precision_score(y_test, y_pred), 4),
        'Recall': round(recall_score(y_test, y_pred), 4),
    }

# %%
# Оценка базовых моделей (без подбора параметров)
base_results = []
for name, model in models.items():
    metrics = evaluate_model(model, X_train, y_train, X_test, y_test)
    base_results.append({
        'Model': name,
        **metrics,
        'Hyperparametres': False
    })
    
base_results = pd.DataFrame(base_results)
display(base_results.sort_values('Accuracy', ascending=False))
# Out:
#                    Model  Accuracy  F1-score  Precision  Recall  \
# 1          Random Forest    0.6918    0.6767     0.7143  0.6429
# 2               CatBoost    0.6774    0.6565     0.7049  0.6143
# 4  HistGradient Boosting    0.6738    0.6486     0.7059  0.6000
# 5            Extra Trees    0.6595    0.6415     0.6800  0.6071
# 0                XGBoost    0.6559    0.6391     0.6746  0.6071
# 3      Gradient Boosting    0.6344    0.6250     0.6439  0.6071
#
#    Hyperparametres
# 1            False
# 2            False
# 4            False
# 5            False
# 0            False
# 3            False

# %% [markdown]
# На первом этапе модели обучались без настройки гиперпараметров. Лучшие показатели точности (Accuracy = 0.6918) и F1-score (0.6767) продемонстрировала модель Random Forest, что говорит о её способности выявлять превышение медианного значения SI. Наихудшие результаты по точности показала модель Gradient Boosting (Accuracy = 0.6344).

# %%
"""
Определяем словарь param_grid с диапазонами гиперпараметров для каждой модели.
- Числовые параметры задаются как кортеж (min, max) и:
  - преобразуются в списки при использовании RandomizedSearchCV,
  - или напрямую используются в Optuna для проб в указанных границах.
- Категориальные параметры задаются списками (например: ['sqrt', 'log2', None]).
Словарь используется для автоматического подбора параметров с помощью разных стратегий оптимизации.
"""

param_grid = {
    'XGBoost': {
        'n_estimators': (100, 500),
        'max_depth': (3, 11),
        'learning_rate': (0.01, 0.3),
        'subsample': (0.5, 1.0),
        'colsample_bytree': (0.5, 1.0),
        'gamma': (0.0, 5.0),
        'min_child_weight': (1, 10),
    },

    'Random Forest': {
        'n_estimators': (100, 300),
        'max_depth': (4, 20),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True],
    },

    'CatBoost': {
        'iterations': (150, 1000),
        'depth': (4, 12),
        'learning_rate': (0.01, 0.3),
        'l2_leaf_reg': (1, 10),
        'border_count': [64, 128, 255],
        'bagging_temperature': (0.0, 1.0),
        'verbose': [False],
    },

    'Gradient Boosting': {
        'n_estimators': (100, 300),
        'learning_rate': (0.01, 0.3),
        'max_depth': (3, 10),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'subsample': (0.5, 1.0),
    },

    'HistGradient Boosting': {
        'max_iter': (100, 300),
        'learning_rate': (0.01, 0.3),
        'max_depth': (3, 11),
        'min_samples_leaf': (1, 25),
        'l2_regularization': (0.0, 1.0),
        'max_bins': [64, 128, 255],
    },

    'Extra Trees': {
        'n_estimators': (100, 300),
        'max_depth': (4, 20),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True],
    }
}

# %%
def convert_grid_for_random_search(grid, n_points=3):
    """
    Преобразует сетку гиперпараметров с диапазонами (кортежи) в списки значений для RandomizedSearchCV.
    - Если параметр задан диапазоном (tuple), генерирует n_points равномерно распределённых значений.
    - Если параметр уже список, оставляет без изменений.
    """
    rs_grid = {}
    for param, vals in grid.items():
        if isinstance(vals, tuple):
            # Диапазон: генерируем n_points значений (int или float)
            if all(isinstance(v, int) for v in vals):
                rs_grid[param] = list(np.linspace(vals[0], vals[1], n_points, dtype=int))
            else:
                rs_grid[param] = list(np.linspace(vals[0], vals[1], n_points))
        elif isinstance(vals, list):
            rs_grid[param] = vals
        else:
            raise ValueError(f"Unknown param type for {param}: {vals}")
    return rs_grid

# Перебор моделей и подбор гиперпараметров с RandomizedSearchCV, используя преобразованную сетку параметров
tuned_results = []
for name in models.keys():
    # Преобразуем сетку из диапазонов в списки для RandomizedSearchCV
    rs_params = convert_grid_for_random_search(param_grid[name], n_points=3)

    search = RandomizedSearchCV(
        estimator=models[name],
        param_distributions=rs_params,
        n_iter=20,
        cv=3,
        scoring='accuracy',
        n_jobs=-1,
        random_state=42
    )
    search.fit(X_train, y_train)

    metrics = evaluate_model(search.best_estimator_, X_train, y_train, X_test, y_test)
    tuned_results.append({
        'Model': name,
        **metrics,
        'Hyperparametres': True
    })

tuned_results = pd.DataFrame(tuned_results)
display(tuned_results.sort_values('Accuracy', ascending=False))
# Out:
#                    Model  Accuracy  F1-score  Precision  Recall  \
# 1          Random Forest    0.6810    0.6590     0.7107  0.6143
# 5            Extra Trees    0.6810    0.6642     0.7040  0.6286
# 0                XGBoost    0.6774    0.6642     0.6953  0.6357
# 3      Gradient Boosting    0.6774    0.6565     0.7049  0.6143
# 2               CatBoost    0.6703    0.6489     0.6967  0.6071
# 4  HistGradient Boosting    0.6595    0.6442     0.6772  0.6143
#
#    Hyperparametres
# 1             True
# 5             True
# 0             True
# 3             True
# 2             True
# 4             True

# %% [markdown]
# После настройки гиперпараметров наблюдается умеренное улучшение метрик. Модель Random Forest сохранила лидирующие позиции по Accuracy (0.6810) и Precision (0.7107), однако уступила по Recall модели XGBoost (Recall = 0.6357). В то же время Extra Trees и Gradient Boosting показали сбалансированные значения F1-score и Recall. Несмотря на настройку, HistGradient Boosting не продемонстрировала значительного улучшения, оставаясь одной из наименее эффективных моделей.

# %%
# Объединение результатов
all_results = pd.concat([base_results, tuned_results])

# Вывод таблицы
display(all_results.sort_values('Accuracy', ascending=False))
# Out:
#                    Model  Accuracy  F1-score  Precision  Recall  \
# 1          Random Forest    0.6918    0.6767     0.7143  0.6429
# 1          Random Forest    0.6810    0.6590     0.7107  0.6143
# 5            Extra Trees    0.6810    0.6642     0.7040  0.6286
# 2               CatBoost    0.6774    0.6565     0.7049  0.6143
# 0                XGBoost    0.6774    0.6642     0.6953  0.6357
# 3      Gradient Boosting    0.6774    0.6565     0.7049  0.6143
# 4  HistGradient Boosting    0.6738    0.6486     0.7059  0.6000
# 2               CatBoost    0.6703    0.6489     0.6967  0.6071
# 5            Extra Trees    0.6595    0.6415     0.6800  0.6071
# 4  HistGradient Boosting    0.6595    0.6442     0.6772  0.6143
# 0                XGBoost    0.6559    0.6391     0.6746  0.6071
# 3      Gradient Boosting    0.6344    0.6250     0.6439  0.6071
#
#    Hyperparametres
# 1            False
# 1             True
# 5             True
# 2            False
# 0             True
# 3             True
# 4            False
# 2             True
# 5            False
# 4             True
# 0            False
# 3            False

# %% [markdown]
# Агрегированная таблица показывает, что Random Forest остаётся стабильным лидером по Accuracy до и после настройки, однако модель XGBoost догоняет по метрикам Recall и F1-score после оптимизации. Некоторые модели, такие как CatBoost и HistGradient Boosting, не продемонстрировали устойчивого улучшения после подбора гиперпараметров.

# %%
# Визуализация сравнения моделей по метрикам (Accuracy, F1-score, Precision, Recall) до и после подбора гиперпараметров
metrics_to_plot = ['Accuracy', 'F1-score', 'Precision', 'Recall']

for metric in metrics_to_plot:
    plt.figure(figsize=(10, 5))
    sns.barplot(data=all_results, x='Model', y=metric, hue='Hyperparametres')
    plt.title(f'Сравнение метрики {metric} до и после подбора параметров')
    plt.ylabel(metric)
    plt.xticks(rotation=15)
    plt.grid(True)
    plt.show()

# %%
# Анализ результатов: определение лучших и худших моделей по метрикам, выбор модели с минимальным RMSE и выявление моделей, у которых тюнинг не дал улучшений
tuned_only = all_results[all_results['Hyperparametres'] == True].copy()
baseline = all_results[all_results['Hyperparametres'] == False].copy()

# Модель, выбранная для дальнейшей оптимизации
chosen_model = all_results.sort_values('Accuracy', ascending=False).iloc[0]['Model']

# Проход по метрикам
for metric in ['Accuracy', 'F1-score', 'Precision', 'Recall']:
    print(f"\nМетрика: {metric}")

    ascending = False

    best_model = all_results.sort_values(metric, ascending=ascending).iloc[0]
    worst_model = all_results.sort_values(metric, ascending=not ascending).iloc[0]

    print(f"Лучшая модель: **{best_model['Model']}** → {metric} = {best_model[metric]:.4f}")
    print(f"Худшая модель: **{worst_model['Model']}** → {metric} = {worst_model[metric]:.4f}")

    # Сравнение тюнингованных с базовыми версиями
    merged = tuned_only.merge(
        baseline,
        on='Model',
        suffixes=('_tuned', '_base')
    ).drop_duplicates('Model')

    stagnant = merged[merged[f'{metric}_tuned'] <= merged[f'{metric}_base']]['Model'].tolist()

    if stagnant:
        print(f"Без улучшений или хуже: {', '.join(sorted(set(stagnant)))}")
# Out:
# Метрика: Accuracy
# Лучшая модель: **Random Forest** → Accuracy = 0.6918
# Худшая модель: **Gradient Boosting** → Accuracy = 0.6344
# Без улучшений или хуже: CatBoost, HistGradient Boosting, Random Forest
#
# Метрика: F1-score
# Лучшая модель: **Random Forest** → F1-score = 0.6767
# Худшая модель: **Gradient Boosting** → F1-score = 0.6250
# Без улучшений или хуже: CatBoost, HistGradient Boosting, Random Forest
#
# Метрика: Precision
# Лучшая модель: **Random Forest** → Precision = 0.7143
# Худшая модель: **Gradient Boosting** → Precision = 0.6439
# Без улучшений или хуже: CatBoost, HistGradient Boosting, Random Forest
#
# Метрика: Recall
# Лучшая модель: **Random Forest** → Recall = 0.6429
# Худшая модель: **HistGradient Boosting** → Recall = 0.6000
# Без улучшений или хуже: CatBoost, Random Forest

# %%
"""
Оптимизация гиперпараметров лучшей модели с помощью Optuna:

1. Определяем лучшую модель по метрике RMSE из предыдущих результатов.
2. Задаём пространство поиска гиперпараметров, учитывая типы.
3. Запускаем Optuna для минимизации RMSE с 5-fold кросс-валидацией.
4. Обучаем финальную модель на оптимальных параметрах.
5. Вычисляем и выводим метрики качества на тесте.
6. Сравниваем финальный результат с предыдущей лучшей версией модели.
"""

# Выбираем лучшую модель
best_model_name = all_results.sort_values('Accuracy', ascending=False).iloc[0]['Model']
print(f"Лучшая модель: {best_model_name}")

model_class = models[best_model_name]
param_space = param_grid[best_model_name]

def objective(trial):
    params = {}
    for param, values in param_space.items():
        # Если диапазон (tuple), предполагаем [min, max]
        if isinstance(values, tuple) and len(values) == 2:
            low, high = values
            if isinstance(low, int) and isinstance(high, int):
                params[param] = trial.suggest_int(param, low, high)
            else:
                params[param] = trial.suggest_float(param, low, high)
        # Если список, то категориальный параметр
        elif isinstance(values, list):
            # Если это список с bool или str/None - categorical
            if all(isinstance(v, bool) for v in values) or all(isinstance(v, (str,type(None))) for v in values):
                params[param] = trial.suggest_categorical(param, values)
            # Если числа — тоже categorical (например дискретные значения)
            elif all(isinstance(v, (int,float)) for v in values):
                params[param] = trial.suggest_categorical(param, values)
            else:
                raise ValueError(f"Unsupported list param type for '{param}': {values}")
        else:
            raise ValueError(f"Unsupported param format for '{param}': {values}")

    params['random_state'] = 42

    model = model_class.__class__(**params)
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    accuracy = cross_val_score(model, X_train, y_train,
                               scoring='accuracy', cv=cv, n_jobs=-1).mean()
    return accuracy

print(f"\nЗапуск Optuna для {best_model_name}...")
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=100, show_progress_bar=True)

print(f"\nЛучшие параметры:")
print(study.best_params)

final_model = model_class.__class__(**study.best_params, random_state=42)
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)

final_accuracy = accuracy_score(y_test, y_pred)
final_f1 = f1_score(y_test, y_pred)
final_precision = precision_score(y_test, y_pred)
final_recall = recall_score(y_test, y_pred)

print("\nФинальные метрики:")
print(f"Accuracy: {final_accuracy:.4f}")
print(f"F1-score: {final_f1:.4f}")
print(f"Precision: {final_precision:.4f}")
print(f"Recall: {final_recall:.4f}")

prev_versions = all_results[all_results['Model'] == best_model_name]
prev_best = prev_versions.sort_values('Accuracy', ascending=False).iloc[0]

print("\nСравнение с предыдущей лучшей версией этой модели (до Optuna):")
print(f"Accuracy было: {prev_best['Accuracy']:.4f} → стало: {final_accuracy:.4f}")
print(f"Улучшение: {final_accuracy - prev_best['Accuracy']:.4f}")
print(f"F1-score было: {prev_best['F1-score']:.4f} → стало: {final_f1:.4f}")
print(f"Улучшение: {final_f1 - prev_best['F1-score']:.4f}")
# Out:
# [I 2025-07-26 11:47:26,679] A new study created in memory with name: no-name-540fe7bc-f5f1-4b34-bcec-f63542c35a15
# Лучшая модель: Random Forest
#
# Запуск Optuna для Random Forest...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-07-26 11:47:27,295] Trial 0 finished with value: 0.6553846153846153 and parameters: {'n_estimators': 298, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 0 with value: 0.6553846153846153.
# [I 2025-07-26 11:47:27,501] Trial 1 finished with value: 0.643076923076923 and parameters: {'n_estimators': 132, 'max_depth': 5, 'min_samples_split': 12, 'min_samples_leaf': 16, 'max_features': 'log2', 'bootstrap': True}. Best is trial 0 with value: 0.6553846153846153.
# [I 2025-07-26 11:47:29,485] Trial 2 finished with value: 0.64 and parameters: {'n_estimators': 224, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 13, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.6553846153846153.
# [I 2025-07-26 11:47:29,703] Trial 3 finished with value: 0.6507692307692308 and parameters: {'n_estimators': 122, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 0 with value: 0.6553846153846153.
# [I 2025-07-26 11:47:32,900] Trial 4 finished with value: 0.6507692307692308 and parameters: {'n_estimators': 285, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.6553846153846153.
# [I 2025-07-26 11:47:33,170] Trial 5 finished with value: 0.6661538461538461 and parameters: {'n_estimators': 150, 'max_depth': 11, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:35,326] Trial 6 finished with value: 0.6384615384615385 and parameters: {'n_estimators': 265, 'max_depth': 11, 'min_samples_split': 3, 'min_samples_leaf': 16, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:35,564] Trial 7 finished with value: 0.6415384615384616 and parameters: {'n_estimators': 113, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 17, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:36,282] Trial 8 finished with value: 0.6630769230769232 and parameters: {'n_estimators': 297, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:36,774] Trial 9 finished with value: 0.6661538461538461 and parameters: {'n_estimators': 230, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:37,042] Trial 10 finished with value: 0.6492307692307693 and parameters: {'n_estimators': 163, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:37,451] Trial 11 finished with value: 0.6461538461538462 and parameters: {'n_estimators': 199, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:37,890] Trial 12 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 192, 'max_depth': 16, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:38,302] Trial 13 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 232, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:38,618] Trial 14 finished with value: 0.6523076923076923 and parameters: {'n_estimators': 161, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:38,904] Trial 15 finished with value: 0.6599999999999999 and parameters: {'n_estimators': 165, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:39,394] Trial 16 finished with value: 0.6523076923076923 and parameters: {'n_estimators': 240, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:39,662] Trial 17 finished with value: 0.6461538461538462 and parameters: {'n_estimators': 147, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 11, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:40,060] Trial 18 finished with value: 0.6507692307692308 and parameters: {'n_estimators': 184, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:42,785] Trial 19 finished with value: 0.6476923076923077 and parameters: {'n_estimators': 212, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:43,016] Trial 20 finished with value: 0.6461538461538462 and parameters: {'n_estimators': 101, 'max_depth': 15, 'min_samples_split': 2, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:43,564] Trial 21 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 254, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:44,240] Trial 22 finished with value: 0.6446153846153846 and parameters: {'n_estimators': 261, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:44,868] Trial 23 finished with value: 0.6461538461538462 and parameters: {'n_estimators': 283, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:45,250] Trial 24 finished with value: 0.6523076923076923 and parameters: {'n_estimators': 176, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:45,624] Trial 25 finished with value: 0.6492307692307693 and parameters: {'n_estimators': 212, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:45,926] Trial 26 finished with value: 0.6384615384615385 and parameters: {'n_estimators': 139, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:46,558] Trial 27 finished with value: 0.6538461538461539 and parameters: {'n_estimators': 278, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:48,260] Trial 28 finished with value: 0.6307692307692307 and parameters: {'n_estimators': 247, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:48,850] Trial 29 finished with value: 0.6553846153846153 and parameters: {'n_estimators': 299, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:49,274] Trial 30 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 215, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:49,554] Trial 31 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 158, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:49,890] Trial 32 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 178, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:50,142] Trial 33 finished with value: 0.6646153846153846 and parameters: {'n_estimators': 150, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:50,426] Trial 34 finished with value: 0.6492307692307693 and parameters: {'n_estimators': 150, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:50,664] Trial 35 finished with value: 0.6476923076923076 and parameters: {'n_estimators': 135, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:52,350] Trial 36 finished with value: 0.6399999999999999 and parameters: {'n_estimators': 122, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:52,808] Trial 37 finished with value: 0.6538461538461539 and parameters: {'n_estimators': 273, 'max_depth': 18, 'min_samples_split': 13, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:53,030] Trial 38 finished with value: 0.6446153846153846 and parameters: {'n_estimators': 124, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:55,228] Trial 39 finished with value: 0.6523076923076923 and parameters: {'n_estimators': 226, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:55,876] Trial 40 finished with value: 0.6415384615384615 and parameters: {'n_estimators': 292, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:56,177] Trial 41 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 173, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:56,460] Trial 42 finished with value: 0.663076923076923 and parameters: {'n_estimators': 149, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:56,778] Trial 43 finished with value: 0.6476923076923077 and parameters: {'n_estimators': 191, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:57,042] Trial 44 finished with value: 0.6492307692307692 and parameters: {'n_estimators': 146, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:57,296] Trial 45 finished with value: 0.6507692307692307 and parameters: {'n_estimators': 128, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:57,611] Trial 46 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 154, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:57,816] Trial 47 finished with value: 0.6415384615384616 and parameters: {'n_estimators': 113, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 9, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:58,158] Trial 48 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 168, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:58,411] Trial 49 finished with value: 0.6538461538461539 and parameters: {'n_estimators': 139, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:59,462] Trial 50 finished with value: 0.6476923076923077 and parameters: {'n_estimators': 111, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:47:59,780] Trial 51 finished with value: 0.6461538461538461 and parameters: {'n_estimators': 158, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 5 with value: 0.6661538461538461.
# [I 2025-07-26 11:48:00,113] Trial 52 finished with value: 0.6676923076923076 and parameters: {'n_estimators': 155, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:00,461] Trial 53 finished with value: 0.6384615384615385 and parameters: {'n_estimators': 184, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 18, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:00,747] Trial 54 finished with value: 0.663076923076923 and parameters: {'n_estimators': 145, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:01,209] Trial 55 finished with value: 0.663076923076923 and parameters: {'n_estimators': 236, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:01,630] Trial 56 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 197, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:02,006] Trial 57 finished with value: 0.6553846153846153 and parameters: {'n_estimators': 164, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:02,368] Trial 58 finished with value: 0.6538461538461537 and parameters: {'n_estimators': 204, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:02,668] Trial 59 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 133, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:03,148] Trial 60 finished with value: 0.6446153846153846 and parameters: {'n_estimators': 265, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 14, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:03,445] Trial 61 finished with value: 0.663076923076923 and parameters: {'n_estimators': 143, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:03,730] Trial 62 finished with value: 0.663076923076923 and parameters: {'n_estimators': 148, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:04,046] Trial 63 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 154, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:04,394] Trial 64 finished with value: 0.6461538461538462 and parameters: {'n_estimators': 170, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:04,754] Trial 65 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 140, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:05,088] Trial 66 finished with value: 0.6446153846153846 and parameters: {'n_estimators': 183, 'max_depth': 17, 'min_samples_split': 13, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:05,612] Trial 67 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 255, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:06,514] Trial 68 finished with value: 0.6369230769230769 and parameters: {'n_estimators': 101, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 14, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:06,751] Trial 69 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 129, 'max_depth': 19, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:07,047] Trial 70 finished with value: 0.6507692307692307 and parameters: {'n_estimators': 117, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:07,501] Trial 71 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 240, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:08,004] Trial 72 finished with value: 0.6507692307692308 and parameters: {'n_estimators': 233, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:08,420] Trial 73 finished with value: 0.64 and parameters: {'n_estimators': 207, 'max_depth': 11, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:08,848] Trial 74 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 224, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:09,293] Trial 75 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 272, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 8, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:09,830] Trial 76 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 290, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:10,132] Trial 77 finished with value: 0.6553846153846153 and parameters: {'n_estimators': 152, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:10,544] Trial 78 finished with value: 0.6584615384615384 and parameters: {'n_estimators': 218, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:10,798] Trial 79 finished with value: 0.6415384615384615 and parameters: {'n_estimators': 158, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 13, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:12,267] Trial 80 finished with value: 0.6476923076923077 and parameters: {'n_estimators': 137, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 7, 'max_features': None, 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:12,553] Trial 81 finished with value: 0.663076923076923 and parameters: {'n_estimators': 145, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:12,833] Trial 82 finished with value: 0.6646153846153846 and parameters: {'n_estimators': 141, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:13,279] Trial 83 finished with value: 0.6492307692307693 and parameters: {'n_estimators': 246, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 13, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:13,611] Trial 84 finished with value: 0.6476923076923077 and parameters: {'n_estimators': 162, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:13,878] Trial 85 finished with value: 0.6569230769230769 and parameters: {'n_estimators': 129, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:14,178] Trial 86 finished with value: 0.6430769230769231 and parameters: {'n_estimators': 142, 'max_depth': 16, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:14,487] Trial 87 finished with value: 0.6599999999999999 and parameters: {'n_estimators': 150, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:14,845] Trial 88 finished with value: 0.6599999999999999 and parameters: {'n_estimators': 178, 'max_depth': 13, 'min_samples_split': 3, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:15,133] Trial 89 finished with value: 0.6492307692307693 and parameters: {'n_estimators': 168, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 14, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:15,485] Trial 90 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 157, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:15,773] Trial 91 finished with value: 0.663076923076923 and parameters: {'n_estimators': 145, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:16,057] Trial 92 finished with value: 0.6615384615384615 and parameters: {'n_estimators': 144, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:16,326] Trial 93 finished with value: 0.6661538461538461 and parameters: {'n_estimators': 134, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:16,561] Trial 94 finished with value: 0.6476923076923076 and parameters: {'n_estimators': 119, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 11, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:16,843] Trial 95 finished with value: 0.6646153846153846 and parameters: {'n_estimators': 135, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:17,083] Trial 96 finished with value: 0.6492307692307692 and parameters: {'n_estimators': 133, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 11, 'max_features': 'log2', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:17,383] Trial 97 finished with value: 0.6523076923076923 and parameters: {'n_estimators': 126, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 52 with value: 0.6676923076923076.
# [I 2025-07-26 11:48:17,699] Trial 98 finished with value: 0.6692307692307693 and parameters: {'n_estimators': 137, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 98 with value: 0.6692307692307693.
# [I 2025-07-26 11:48:19,089] Trial 99 finished with value: 0.6461538461538461 and parameters: {'n_estimators': 110, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': True}. Best is trial 98 with value: 0.6692307692307693.
#
# Лучшие параметры:
# {'n_estimators': 137, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': True}
#
# Финальные метрики:
# Accuracy: 0.6989
# F1-score: 0.6794
# Precision: 0.7295
# Recall: 0.6357
#
# Сравнение с предыдущей лучшей версией этой модели (до Optuna):
# Accuracy было: 0.6918 → стало: 0.6989
# Улучшение: 0.0071
# F1-score было: 0.6767 → стало: 0.6794
# Улучшение: 0.0027

# %% [markdown]
# Оптимизация гиперпараметров с помощью Optuna позволила улучшить модель Random Forest, повысив Accuracy до 0.6989 и F1-score до 0.6794, что подтверждает эффективность подхода. Это подтверждает эффективность выбранного подхода и выделяет Random Forest как предпочтительный вариант для решения задачи классификации превышения медианного значения SI.

# %%
target_model = best_model_name

# 1. Получаем базовую версию (без подбора)
base_row = all_results[(all_results['Model'] == target_model) & (all_results['Hyperparametres'] == False)].sort_values('Accuracy', ascending=False).iloc[0]

# 2. С RandomizedSearch
random_row = all_results[(all_results['Model'] == target_model) & (all_results['Hyperparametres'] == True)].sort_values('Accuracy', ascending=False).iloc[0]

# 3. Финальные метрики Optuna (берём из переменных после обучения)
optuna_metrics = {
    'Accuracy': final_accuracy,
    'F1-score': final_f1,
    'Precision': final_precision,
    'Recall': final_recall
}

# 4. Собираем всё в DataFrame
progress = pd.DataFrame({
    'Этап': ['Без подбора', 'RandomizedSearch', 'Optuna'],
    'Accuracy': [base_row['Accuracy'], random_row['Accuracy'], optuna_metrics['Accuracy']],
    'F1-score': [base_row['F1-score'], random_row['F1-score'], optuna_metrics['F1-score']],
    'Precision': [base_row['Precision'], random_row['Precision'], optuna_metrics['Precision']],
    'Recall': [base_row['Recall'], random_row['Recall'], optuna_metrics['Recall']],
})

# 5. Строим графики для каждой метрики
for metric in ['Accuracy', 'F1-score', 'Precision', 'Recall']:
    plt.figure(figsize=(8, 5))
    plt.plot(progress['Этап'], progress[metric], marker='o', linewidth=2)
    plt.title(f'Изменение метрики {metric} по этапам — {target_model}')
    plt.xlabel('Этап')
    plt.ylabel(metric)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Исходя из анализа, оптимальной моделью для классификации превышения медианного значения SI является Random Forest с настройкой гиперпараметров через Optuna. Модель демонстрирует высокую точность и сбалансированность между полнотой и точностью, что важно для надёжного предсказания.
