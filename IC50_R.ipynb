# %%
# Импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from xgboost import XGBRegressor
from sklearn.ensemble import (RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor)
from catboost import CatBoostRegressor
from sklearn.model_selection import cross_val_score, KFold, train_test_split, RandomizedSearchCV
import optuna

# %%
# Загружаем данные
data = pd.read_csv('data/ic50_data.csv')

# %%
# Разделяем данные
X = data.drop(columns=['IC50_log'])
y = data['IC50_log']

# %%
# Разделение данных (70% тренировочные, 30% тестовые)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Тренировочные данные: {X_train.shape[0]}")
print(f"Тестовые данные: {X_test.shape[0]}")
# Out:
# Тренировочные данные: 650
# Тестовые данные: 279

# %%
# Инициализация моделей со стандартными параметрами
models = {
    'XGBoost': XGBRegressor(random_state=42),
    'Random Forest': RandomForestRegressor(random_state=42),
    'CatBoost': CatBoostRegressor(verbose=0, random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(random_state=42),
    'HistGradient Boosting': HistGradientBoostingRegressor(random_state=42),
    'Extra Trees': ExtraTreesRegressor(random_state=42),
}

# %%
# Функция для оценки моделей
def evaluate_model(model, X_train, y_train, X_test, y_test):
    """Оценивает модель и возвращает метрики"""
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    return {
        'RMSE': round(np.sqrt(mean_squared_error(y_test, y_pred)), 4),
        'MAE': round(mean_absolute_error(y_test, y_pred), 4),
        'R2': round(r2_score(y_test, y_pred), 4)
    }

# %%
# Оценка базовых моделей (без подбора параметров)
base_results = []
for name, model in models.items():
    metrics = evaluate_model(model, X_train, y_train, X_test, y_test)
    base_results.append({
        'Model': name,
        **metrics,
        'Hyperparametres': False
    })
    
base_results = pd.DataFrame(base_results)
display(base_results.sort_values('RMSE', ascending=False))
# Out:
#                    Model    RMSE     MAE      R2  Hyperparametres
# 0                XGBoost  1.2472  0.9072  0.4378            False
# 4  HistGradient Boosting  1.1718  0.8873  0.5037            False
# 1          Random Forest  1.1515  0.8669  0.5208            False
# 3      Gradient Boosting  1.1478  0.8887  0.5238            False
# 2               CatBoost  1.1412  0.8660  0.5293            False
# 5            Extra Trees  1.1079  0.8151  0.5563            False

# %% [markdown]
# На первом этапе были обучены модели с параметрами по умолчанию. Лучшую производительность показала модель Extra Trees, достигнув наименьшего значения RMSE (1.1079) и самого высокого R2 (0.5563), что свидетельствует о высоком качестве предсказаний. В то же время XGBoost продемонстрировал наихудший результат по всем метрикам, что объясняется отсутствием настройки и возможной переоценкой сложности модели на этом этапе.

# %%
"""
Определяем словарь param_grid с диапазонами гиперпараметров для каждой модели.
- Числовые параметры задаются как кортеж (min, max) и:
  - преобразуются в списки при использовании RandomizedSearchCV,
  - или напрямую используются в Optuna для проб в указанных границах.
- Категориальные параметры задаются списками (например: ['sqrt', 'log2', None]).
Словарь используется для автоматического подбора параметров с помощью разных стратегий оптимизации.
"""

param_grid = {
    'XGBoost': {
        'n_estimators': (100, 500),
        'max_depth': (3, 11),
        'learning_rate': (0.01, 0.3),
        'subsample': (0.5, 1.0),
        'colsample_bytree': (0.5, 1.0),
        'gamma': (0.0, 5.0),
        'min_child_weight': (1, 10),
    },

    'Random Forest': {
        'n_estimators': (100, 300),
        'max_depth': (4, 20),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True],
    },

    'CatBoost': {
        'iterations': (150, 1000),
        'depth': (4, 12),
        'learning_rate': (0.01, 0.3),
        'l2_leaf_reg': (1, 10),
        'border_count': [64, 128, 255],
        'bagging_temperature': (0.0, 1.0),
        'verbose': [False],
    },

    'Gradient Boosting': {
        'n_estimators': (100, 300),
        'learning_rate': (0.01, 0.3),
        'max_depth': (3, 10),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'subsample': (0.5, 1.0),
    },

    'HistGradient Boosting': {
        'max_iter': (100, 300),
        'learning_rate': (0.01, 0.3),
        'max_depth': (3, 11),
        'min_samples_leaf': (1, 25),
        'l2_regularization': (0.0, 1.0),
        'max_bins': [64, 128, 255],
    },

    'Extra Trees': {
        'n_estimators': (100, 300),
        'max_depth': (4, 20),
        'min_samples_split': (2, 18),
        'min_samples_leaf': (1, 18),
        'max_features': ['sqrt', 'log2', None],
        'bootstrap': [True],
    }
}

# %%
def convert_grid_for_random_search(grid, n_points=3):
    """
    Преобразует сетку гиперпараметров с диапазонами (кортежи) в списки значений для RandomizedSearchCV.
    - Если параметр задан диапазоном (tuple), генерирует n_points равномерно распределённых значений.
    - Если параметр уже список, оставляет без изменений.
    """
    rs_grid = {}
    for param, vals in grid.items():
        if isinstance(vals, tuple):
            # Генерируем значения в диапазоне
            if all(isinstance(v, int) for v in vals):
                rs_grid[param] = list(np.linspace(vals[0], vals[1], n_points, dtype=int))
            else:
                rs_grid[param] = list(np.linspace(vals[0], vals[1], n_points))
        elif isinstance(vals, list):
            rs_grid[param] = vals
        else:
            raise ValueError(f"Unknown param type for {param}: {vals}")
    return rs_grid


# Перебор моделей и подбор гиперпараметров с RandomizedSearchCV, используя преобразованную сетку параметров
tuned_results = []
for name in models.keys():
    # Преобразуем сетку из диапазонов в списки для RandomizedSearchCV
    rs_params = convert_grid_for_random_search(param_grid[name], n_points=3)

    search = RandomizedSearchCV(
        estimator=models[name],
        param_distributions=rs_params,
        n_iter=20,
        cv=3,
        scoring='neg_root_mean_squared_error',
        n_jobs=-1,
        random_state=42
    )
    search.fit(X_train, y_train)

    metrics = evaluate_model(search.best_estimator_, X_train, y_train, X_test, y_test)
    tuned_results.append({
        'Model': name,
        **metrics,
        'Hyperparametres': True
    })

tuned_results = pd.DataFrame(tuned_results)
display(tuned_results.sort_values('RMSE', ascending=True))
# Out:
#                    Model    RMSE     MAE      R2  Hyperparametres
# 0                XGBoost  1.0957  0.8650  0.5661             True
# 2               CatBoost  1.1060  0.8742  0.5579             True
# 5            Extra Trees  1.1132  0.8895  0.5521             True
# 3      Gradient Boosting  1.1216  0.8758  0.5453             True
# 1          Random Forest  1.1384  0.8880  0.5316             True
# 4  HistGradient Boosting  1.1386  0.9024  0.5315             True

# %% [markdown]
# После настройки гиперпараметров все модели показали улучшение, особенно заметное у XGBoost, который вышел на первое место с RMSE = 1.0957 и наибольшим R2 = 0.5661. Результаты демонстрируют высокую зависимость качества предсказаний от гиперпараметров и необходимость их подбора. Extra Trees хоть и осталась в тройке лидеров, не показала существенного улучшения по сравнению с дефолтной версией.

# %%
# Объединение результатов
all_results = pd.concat([base_results, tuned_results])

# Вывод таблицы
display(all_results.sort_values('RMSE', ascending=True))
# Out:
#                    Model    RMSE     MAE      R2  Hyperparametres
# 0                XGBoost  1.0957  0.8650  0.5661             True
# 2               CatBoost  1.1060  0.8742  0.5579             True
# 5            Extra Trees  1.1079  0.8151  0.5563            False
# 5            Extra Trees  1.1132  0.8895  0.5521             True
# 3      Gradient Boosting  1.1216  0.8758  0.5453             True
# 1          Random Forest  1.1384  0.8880  0.5316             True
# 4  HistGradient Boosting  1.1386  0.9024  0.5315             True
# 2               CatBoost  1.1412  0.8660  0.5293            False
# 3      Gradient Boosting  1.1478  0.8887  0.5238            False
# 1          Random Forest  1.1515  0.8669  0.5208            False
# 4  HistGradient Boosting  1.1718  0.8873  0.5037            False
# 0                XGBoost  1.2472  0.9072  0.4378            False

# %% [markdown]
# Агрегированная таблица демонстрирует общий прогресс моделей. XGBoost преобразовался из худшего варианта в лидера, что подчёркивает важность подбора гиперпараметров. При этом Extra Trees хоть и остаётся сильным претендентом по MAE, не улучшила RMSE и R2, что может свидетельствовать об ограниченном потенциале модели в рамках текущего подхода.

# %%
# Визуализация сравнения моделей по метрикам (RMSE, MAE, R2) до и после подбора гиперпараметров
metrics_to_plot = ['RMSE', 'MAE', 'R2']

for metric in metrics_to_plot:
    plt.figure(figsize=(10, 5))
    sns.barplot(data=all_results, x='Model', y=metric, hue='Hyperparametres')
    plt.title(f'Сравнение метрики {metric} до и после подбора параметров')
    plt.ylabel(metric)
    plt.xticks(rotation=15)
    plt.grid(True)
    plt.show()

# %%
# Анализ результатов: определение лучших и худших моделей по метрикам, выбор модели с минимальным RMSE и выявление моделей, у которых тюнинг не дал улучшений
tuned_only = all_results[all_results['Hyperparametres'] == True].copy()
baseline = all_results[all_results['Hyperparametres'] == False].copy()

# Модель, выбранная для дальнейшей оптимизации
chosen_model = all_results.sort_values('RMSE').iloc[0]['Model']

# Проход по метрикам
for metric in ['RMSE', 'MAE', 'R2']:
    print(f"\nМетрика: {metric}")

    ascending = metric != 'R2'  # для R2 наоборот: чем больше — тем лучше

    best_model = all_results.sort_values(metric, ascending=ascending).iloc[0]
    worst_model = all_results.sort_values(metric, ascending=not ascending).iloc[0]

    print(f"Лучшая модель: **{best_model['Model']}** → {metric} = {best_model[metric]:.4f}")
    print(f"Худшая модель: **{worst_model['Model']}** → {metric} = {worst_model[metric]:.4f}")


    # Сравнение тюнингованных с базовыми версиями
    merged = tuned_only.merge(
        baseline,
        on='Model',
        suffixes=('_tuned', '_base')
    ).drop_duplicates('Model')

    if metric == 'R2':
        stagnant = merged[merged[f'{metric}_tuned'] <= merged[f'{metric}_base']]['Model'].tolist()
    else:
        stagnant = merged[merged[f'{metric}_tuned'] >= merged[f'{metric}_base']]['Model'].tolist()

    if stagnant:
        print(f"Без улучшений или хуже: {', '.join(sorted(set(stagnant)))}")
# Out:
# Метрика: RMSE
# Лучшая модель: **XGBoost** → RMSE = 1.0957
# Худшая модель: **XGBoost** → RMSE = 1.2472
# Без улучшений или хуже: Extra Trees
#
# Метрика: MAE
# Лучшая модель: **Extra Trees** → MAE = 0.8151
# Худшая модель: **XGBoost** → MAE = 0.9072
# Без улучшений или хуже: CatBoost, Extra Trees, HistGradient Boosting, Random Forest
#
# Метрика: R2
# Лучшая модель: **XGBoost** → R2 = 0.5661
# Худшая модель: **XGBoost** → R2 = 0.4378
# Без улучшений или хуже: Extra Trees

# %%
"""
Оптимизация гиперпараметров лучшей модели с помощью Optuna:

1. Определяем лучшую модель по метрике RMSE из предыдущих результатов.
2. Задаём пространство поиска гиперпараметров, учитывая типы.
3. Запускаем Optuna для минимизации RMSE с 5-fold кросс-валидацией.
4. Обучаем финальную модель на оптимальных параметрах.
5. Вычисляем и выводим метрики качества на тесте.
6. Сравниваем финальный результат с предыдущей лучшей версией модели.
"""

# Выбираем лучшую модель
best_model_name = all_results.sort_values('RMSE').iloc[0]['Model']
print(f"Лучшая модель: {best_model_name}")

model_class = models[best_model_name]
param_space = param_grid[best_model_name]

def objective(trial):
    params = {}
    for param, values in param_space.items():
        # Если диапазон (tuple), предполагаем [min, max]
        if isinstance(values, tuple) and len(values) == 2:
            low, high = values
            if isinstance(low, int) and isinstance(high, int):
                params[param] = trial.suggest_int(param, low, high)
            else:
                params[param] = trial.suggest_float(param, low, high)
        # Если список, то категориальный параметр
        elif isinstance(values, list):
            # Если это список с bool или str/None - категориальный
            if all(isinstance(v, bool) for v in values) or all(isinstance(v, (str,type(None))) for v in values):
                params[param] = trial.suggest_categorical(param, values)
            # Если числа — тоже категориальный (например дискретные значения)
            elif all(isinstance(v, (int,float)) for v in values):
                params[param] = trial.suggest_categorical(param, values)
            else:
                raise ValueError(f"Unsupported list param type for '{param}': {values}")
        else:
            raise ValueError(f"Unsupported param format for '{param}': {values}")

    params['random_state'] = 42

    model = model_class.__class__(**params)
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    neg_rmse = cross_val_score(model, X_train, y_train,
                               scoring='neg_root_mean_squared_error', cv=cv, n_jobs=-1).mean()
    return -neg_rmse

print(f"\nЗапуск Optuna для {best_model_name}...")
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=100, show_progress_bar=True)

print(f"\nЛучшие параметры:")
print(study.best_params)

final_model = model_class.__class__(**study.best_params, random_state=42)
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)

final_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
final_mae = mean_absolute_error(y_test, y_pred)
final_r2 = r2_score(y_test, y_pred)

print("\nФинальные метрики:")
print(f"RMSE: {final_rmse:.4f}")
print(f"MAE: {final_mae:.4f}")
print(f"R2: {final_r2:.4f}")

prev_versions = all_results[all_results['Model'] == best_model_name]
prev_best = prev_versions.sort_values('RMSE').iloc[0]

print("\nСравнение с предыдущей лучшей версией этой модели (до Optuna):")
print(f"RMSE было: {prev_best['RMSE']:.4f} → стало: {final_rmse:.4f}")
print(f"Улучшение: {prev_best['RMSE'] - final_rmse:.4f}")
print(f"R2 было: {prev_best['R2']:.4f} → стало: {final_r2:.4f}")
print(f"Улучшение: {prev_best['R2'] - final_r2:.4f}")
# Out:
# [I 2025-07-26 00:46:55,080] A new study created in memory with name: no-name-7a9ff99b-6ff3-47eb-92f4-66bf4d1a475e
# Лучшая модель: XGBoost
#
# Запуск Optuna для XGBoost...
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-07-26 00:46:55,632] Trial 0 finished with value: 1.3528207856310999 and parameters: {'n_estimators': 250, 'max_depth': 11, 'learning_rate': 0.22227824312530747, 'subsample': 0.7993292420985183, 'colsample_bytree': 0.5780093202212182, 'gamma': 0.7799726016810132, 'min_child_weight': 1}. Best is trial 0 with value: 1.3528207856310999.
# [I 2025-07-26 00:46:56,122] Trial 1 finished with value: 1.3090848726681905 and parameters: {'n_estimators': 447, 'max_depth': 8, 'learning_rate': 0.21534104756085318, 'subsample': 0.5102922471479012, 'colsample_bytree': 0.9849549260809971, 'gamma': 4.162213204002109, 'min_child_weight': 3}. Best is trial 1 with value: 1.3090848726681905.
# [I 2025-07-26 00:46:56,464] Trial 2 finished with value: 1.2559631645589306 and parameters: {'n_estimators': 172, 'max_depth': 4, 'learning_rate': 0.09823025045826593, 'subsample': 0.762378215816119, 'colsample_bytree': 0.7159725093210578, 'gamma': 1.4561457009902097, 'min_child_weight': 7}. Best is trial 2 with value: 1.2559631645589306.
# [I 2025-07-26 00:46:56,844] Trial 3 finished with value: 1.2742815187745076 and parameters: {'n_estimators': 155, 'max_depth': 5, 'learning_rate': 0.11624493455517058, 'subsample': 0.728034992108518, 'colsample_bytree': 0.8925879806965068, 'gamma': 0.9983689107917987, 'min_child_weight': 6}. Best is trial 2 with value: 1.2559631645589306.
# [I 2025-07-26 00:46:57,147] Trial 4 finished with value: 1.2764668951373563 and parameters: {'n_estimators': 337, 'max_depth': 3, 'learning_rate': 0.1861880070514171, 'subsample': 0.5852620618436457, 'colsample_bytree': 0.5325257964926398, 'gamma': 4.7444276862666666, 'min_child_weight': 10}. Best is trial 2 with value: 1.2559631645589306.
# [I 2025-07-26 00:46:58,142] Trial 5 finished with value: 1.2596910704953495 and parameters: {'n_estimators': 424, 'max_depth': 5, 'learning_rate': 0.03832491306185132, 'subsample': 0.8421165132560784, 'colsample_bytree': 0.7200762468698007, 'gamma': 0.6101911742238941, 'min_child_weight': 5}. Best is trial 2 with value: 1.2559631645589306.
# [I 2025-07-26 00:46:58,480] Trial 6 finished with value: 1.253276948515515 and parameters: {'n_estimators': 113, 'max_depth': 11, 'learning_rate': 0.0850461946640049, 'subsample': 0.831261142176991, 'colsample_bytree': 0.6558555380447055, 'gamma': 2.600340105889054, 'min_child_weight': 6}. Best is trial 6 with value: 1.253276948515515.
# [I 2025-07-26 00:46:58,743] Trial 7 finished with value: 1.2730415562832817 and parameters: {'n_estimators': 174, 'max_depth': 11, 'learning_rate': 0.2347885187747232, 'subsample': 0.9697494707820946, 'colsample_bytree': 0.9474136752138245, 'gamma': 2.9894998940554256, 'min_child_weight': 10}. Best is trial 6 with value: 1.253276948515515.
# [I 2025-07-26 00:46:59,142] Trial 8 finished with value: 1.2233657221045975 and parameters: {'n_estimators': 135, 'max_depth': 4, 'learning_rate': 0.023115913784056037, 'subsample': 0.6626651653816322, 'colsample_bytree': 0.6943386448447411, 'gamma': 1.3567451588694794, 'min_child_weight': 9}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:46:59,791] Trial 9 finished with value: 1.3455323628404887 and parameters: {'n_estimators': 243, 'max_depth': 5, 'learning_rate': 0.16738186411589207, 'subsample': 0.5704621124873813, 'colsample_bytree': 0.9010984903770198, 'gamma': 0.3727532183988541, 'min_child_weight': 10}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:00,205] Trial 10 finished with value: 1.3669205059795324 and parameters: {'n_estimators': 305, 'max_depth': 8, 'learning_rate': 0.29116576212848116, 'subsample': 0.673425445703311, 'colsample_bytree': 0.8200442512337782, 'gamma': 1.9014648012590543, 'min_child_weight': 8}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:01,241] Trial 11 finished with value: 1.3306691920779254 and parameters: {'n_estimators': 102, 'max_depth': 9, 'learning_rate': 0.011197345246287155, 'subsample': 0.9115111923418354, 'colsample_bytree': 0.6419296393992733, 'gamma': 2.9744634749046277, 'min_child_weight': 4}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:01,590] Trial 12 finished with value: 1.2509636154449946 and parameters: {'n_estimators': 112, 'max_depth': 7, 'learning_rate': 0.07231657166062727, 'subsample': 0.664078075290053, 'colsample_bytree': 0.640535380158451, 'gamma': 2.3421348647931386, 'min_child_weight': 8}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:02,291] Trial 13 finished with value: 1.2438578971784664 and parameters: {'n_estimators': 229, 'max_depth': 6, 'learning_rate': 0.037146128722234655, 'subsample': 0.6738167152482915, 'colsample_bytree': 0.6248773175738308, 'gamma': 1.9092443998697042, 'min_child_weight': 8}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:03,478] Trial 14 finished with value: 1.2363408374140445 and parameters: {'n_estimators': 229, 'max_depth': 6, 'learning_rate': 0.011009132212853975, 'subsample': 0.643219489778296, 'colsample_bytree': 0.7916135769831638, 'gamma': 1.65289833992663, 'min_child_weight': 8}. Best is trial 8 with value: 1.2233657221045975.
# [I 2025-07-26 00:47:04,107] Trial 15 finished with value: 1.2187613566145867 and parameters: {'n_estimators': 374, 'max_depth': 3, 'learning_rate': 0.011924234234652865, 'subsample': 0.6158050881935151, 'colsample_bytree': 0.8016960128204224, 'gamma': 1.3938675311341482, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:04,732] Trial 16 finished with value: 1.34060432148716 and parameters: {'n_estimators': 372, 'max_depth': 3, 'learning_rate': 0.14117463073450645, 'subsample': 0.5812227399315743, 'colsample_bytree': 0.8003979990890752, 'gamma': 0.02641488392022051, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:05,379] Trial 17 finished with value: 1.2518337610854533 and parameters: {'n_estimators': 384, 'max_depth': 3, 'learning_rate': 0.05772444068767399, 'subsample': 0.5056601521163473, 'colsample_bytree': 0.8469322067804477, 'gamma': 1.2185732001168905, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:05,859] Trial 18 finished with value: 1.2442288137415733 and parameters: {'n_estimators': 489, 'max_depth': 4, 'learning_rate': 0.13159473294088322, 'subsample': 0.7294842713362091, 'colsample_bytree': 0.7405295729116649, 'gamma': 3.6348237589402244, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:06,405] Trial 19 finished with value: 1.2381223945417759 and parameters: {'n_estimators': 303, 'max_depth': 4, 'learning_rate': 0.05311778010300265, 'subsample': 0.6277506153557257, 'colsample_bytree': 0.6818184040164034, 'gamma': 2.2688573671034957, 'min_child_weight': 2}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:07,003] Trial 20 finished with value: 1.272424111945832 and parameters: {'n_estimators': 352, 'max_depth': 3, 'learning_rate': 0.10450812055836484, 'subsample': 0.55184290162289, 'colsample_bytree': 0.7752847229001598, 'gamma': 0.0031663742016290186, 'min_child_weight': 5}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:08,038] Trial 21 finished with value: 1.2289251612067684 and parameters: {'n_estimators': 227, 'max_depth': 6, 'learning_rate': 0.01886964584470055, 'subsample': 0.632602272284079, 'colsample_bytree': 0.8560564747030269, 'gamma': 1.5821042506935443, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:08,889] Trial 22 finished with value: 1.2434482999742391 and parameters: {'n_estimators': 195, 'max_depth': 6, 'learning_rate': 0.029242687222816886, 'subsample': 0.6223958981703062, 'colsample_bytree': 0.8635397961710272, 'gamma': 1.2781145981872075, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:09,695] Trial 23 finished with value: 1.2317996547374221 and parameters: {'n_estimators': 278, 'max_depth': 4, 'learning_rate': 0.010532853455384492, 'subsample': 0.7020843771180814, 'colsample_bytree': 0.7621030135250426, 'gamma': 1.857558829757556, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:10,241] Trial 24 finished with value: 1.2656849897964393 and parameters: {'n_estimators': 146, 'max_depth': 5, 'learning_rate': 0.05736890185229808, 'subsample': 0.6127642441796542, 'colsample_bytree': 0.9204871391696174, 'gamma': 1.014998880870921, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:10,744] Trial 25 finished with value: 1.2527241988631572 and parameters: {'n_estimators': 202, 'max_depth': 7, 'learning_rate': 0.07852406917920511, 'subsample': 0.6951483991717232, 'colsample_bytree': 0.8270750352042042, 'gamma': 1.5169714312475555, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:11,644] Trial 26 finished with value: 1.252197761418181 and parameters: {'n_estimators': 405, 'max_depth': 4, 'learning_rate': 0.03301879781632938, 'subsample': 0.5464272165421258, 'colsample_bytree': 0.6920574096043153, 'gamma': 0.5598063886894289, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:12,216] Trial 27 finished with value: 1.2389077934757036 and parameters: {'n_estimators': 278, 'max_depth': 7, 'learning_rate': 0.0659573444327019, 'subsample': 0.7748822320900216, 'colsample_bytree': 0.862580774849707, 'gamma': 2.5154556076748222, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:12,609] Trial 28 finished with value: 1.3594762536147322 and parameters: {'n_estimators': 340, 'max_depth': 3, 'learning_rate': 0.29064844277198326, 'subsample': 0.6045924731664146, 'colsample_bytree': 0.7526972243506965, 'gamma': 2.061263810064461, 'min_child_weight': 8}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:13,361] Trial 29 finished with value: 1.2561924894912688 and parameters: {'n_estimators': 141, 'max_depth': 10, 'learning_rate': 0.036899380689191845, 'subsample': 0.6501459784982042, 'colsample_bytree': 0.5845591163000415, 'gamma': 0.8736615313288476, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:13,793] Trial 30 finished with value: 1.2554197767860629 and parameters: {'n_estimators': 277, 'max_depth': 6, 'learning_rate': 0.09192900128340079, 'subsample': 0.7940651125130589, 'colsample_bytree': 0.5943934800465827, 'gamma': 2.8679621689350148, 'min_child_weight': 1}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:14,548] Trial 31 finished with value: 1.2240567665154263 and parameters: {'n_estimators': 270, 'max_depth': 4, 'learning_rate': 0.01821075514640165, 'subsample': 0.7112900925953489, 'colsample_bytree': 0.7713307622679801, 'gamma': 1.7282376838828284, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:15,181] Trial 32 finished with value: 1.2218590494344697 and parameters: {'n_estimators': 217, 'max_depth': 4, 'learning_rate': 0.025506586475819513, 'subsample': 0.7016684407794432, 'colsample_bytree': 0.8123607087166168, 'gamma': 1.567262597245973, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:15,747] Trial 33 finished with value: 1.2322011080911888 and parameters: {'n_estimators': 204, 'max_depth': 4, 'learning_rate': 0.044228642521722206, 'subsample': 0.7352496150971101, 'colsample_bytree': 0.7220454499747663, 'gamma': 1.2617827758193563, 'min_child_weight': 8}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:16,473] Trial 34 finished with value: 1.2349411090094429 and parameters: {'n_estimators': 252, 'max_depth': 5, 'learning_rate': 0.025402282504760905, 'subsample': 0.7011316007083335, 'colsample_bytree': 0.6894623010354383, 'gamma': 2.156876849431665, 'min_child_weight': 6}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:17,243] Trial 35 finished with value: 1.2664005706633588 and parameters: {'n_estimators': 443, 'max_depth': 4, 'learning_rate': 0.051518956643014036, 'subsample': 0.7485066769201397, 'colsample_bytree': 0.8001205823756932, 'gamma': 1.0380469050651946, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:17,581] Trial 36 finished with value: 1.2908456293478348 and parameters: {'n_estimators': 325, 'max_depth': 3, 'learning_rate': 0.20966548730617757, 'subsample': 0.6941477055491648, 'colsample_bytree': 0.5137604380605459, 'gamma': 1.6501013059729281, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:17,843] Trial 37 finished with value: 1.221532040768908 and parameters: {'n_estimators': 167, 'max_depth': 5, 'learning_rate': 0.11056182554498759, 'subsample': 0.8257052704239054, 'colsample_bytree': 0.7465016903098708, 'gamma': 4.991417930830018, 'min_child_weight': 4}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:18,125] Trial 38 finished with value: 1.2483727163637393 and parameters: {'n_estimators': 173, 'max_depth': 5, 'learning_rate': 0.11222739707957322, 'subsample': 0.8705732468306884, 'colsample_bytree': 0.7322467733255499, 'gamma': 4.538677753235225, 'min_child_weight': 3}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:18,340] Trial 39 finished with value: 1.2615608376551335 and parameters: {'n_estimators': 134, 'max_depth': 5, 'learning_rate': 0.24082486321289065, 'subsample': 0.8138183674520876, 'colsample_bytree': 0.9556120354709675, 'gamma': 3.775663283784305, 'min_child_weight': 4}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:18,572] Trial 40 finished with value: 1.2311432358686871 and parameters: {'n_estimators': 169, 'max_depth': 3, 'learning_rate': 0.16747171463571267, 'subsample': 0.8661523227701957, 'colsample_bytree': 0.7020059788805565, 'gamma': 4.303037842964206, 'min_child_weight': 4}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:19,032] Trial 41 finished with value: 1.2270870713711743 and parameters: {'n_estimators': 188, 'max_depth': 4, 'learning_rate': 0.02282904948470911, 'subsample': 0.7788499550740096, 'colsample_bytree': 0.7673732646759405, 'gamma': 4.865682650210943, 'min_child_weight': 3}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:19,486] Trial 42 finished with value: 1.2322523174402664 and parameters: {'n_estimators': 257, 'max_depth': 5, 'learning_rate': 0.06642724272738214, 'subsample': 0.7157376079201577, 'colsample_bytree': 0.8311554812252515, 'gamma': 3.3215487634881953, 'min_child_weight': 5}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:19,865] Trial 43 finished with value: 1.243457918609825 and parameters: {'n_estimators': 216, 'max_depth': 4, 'learning_rate': 0.08960997035888564, 'subsample': 0.9443096783813315, 'colsample_bytree': 0.6684042487744952, 'gamma': 0.6414288102562055, 'min_child_weight': 6}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:20,230] Trial 44 finished with value: 1.2344989711591448 and parameters: {'n_estimators': 125, 'max_depth': 4, 'learning_rate': 0.04109510827237068, 'subsample': 0.7520590419469847, 'colsample_bytree': 0.7857611821261021, 'gamma': 2.711041466661531, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:20,564] Trial 45 finished with value: 1.2863060106945194 and parameters: {'n_estimators': 156, 'max_depth': 3, 'learning_rate': 0.13199925860768053, 'subsample': 0.6767223480145864, 'colsample_bytree': 0.8862304151088662, 'gamma': 1.8150101929071494, 'min_child_weight': 5}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:21,659] Trial 46 finished with value: 1.2499420315839385 and parameters: {'n_estimators': 156, 'max_depth': 8, 'learning_rate': 0.021507702938705735, 'subsample': 0.850074684231123, 'colsample_bytree': 0.7114019843530438, 'gamma': 1.3838053644714392, 'min_child_weight': 8}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:22,173] Trial 47 finished with value: 1.2692229825217534 and parameters: {'n_estimators': 180, 'max_depth': 5, 'learning_rate': 0.07795060924708644, 'subsample': 0.8131839251000547, 'colsample_bytree': 0.8163141951134235, 'gamma': 0.7776285809294312, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:22,605] Trial 48 finished with value: 1.3443305915476287 and parameters: {'n_estimators': 261, 'max_depth': 3, 'learning_rate': 0.18923089361270984, 'subsample': 0.5888199125946466, 'colsample_bytree': 0.7498047731357881, 'gamma': 0.3218188760874281, 'min_child_weight': 7}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:23,409] Trial 49 finished with value: 1.242651159807885 and parameters: {'n_estimators': 324, 'max_depth': 4, 'learning_rate': 0.03904144300144709, 'subsample': 0.6547373385078089, 'colsample_bytree': 0.810781105458929, 'gamma': 1.0659445913551724, 'min_child_weight': 6}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:23,641] Trial 50 finished with value: 1.2289846408914373 and parameters: {'n_estimators': 101, 'max_depth': 3, 'learning_rate': 0.04890273780813849, 'subsample': 0.5501570722292158, 'colsample_bytree': 0.7814601441307187, 'gamma': 2.3787003708121612, 'min_child_weight': 8}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:24,164] Trial 51 finished with value: 1.2315676485254952 and parameters: {'n_estimators': 189, 'max_depth': 4, 'learning_rate': 0.018377879736100028, 'subsample': 0.7752051204500716, 'colsample_bytree': 0.7542815253472328, 'gamma': 4.954289206954381, 'min_child_weight': 3}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:24,722] Trial 52 finished with value: 1.2268715749658194 and parameters: {'n_estimators': 241, 'max_depth': 4, 'learning_rate': 0.021938627709781645, 'subsample': 0.7890378054466172, 'colsample_bytree': 0.770072675491864, 'gamma': 4.655789338036684, 'min_child_weight': 2}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:25,305] Trial 53 finished with value: 1.2293511408564894 and parameters: {'n_estimators': 238, 'max_depth': 5, 'learning_rate': 0.02985582164433759, 'subsample': 0.7275736927570079, 'colsample_bytree': 0.8411915485447474, 'gamma': 4.595135608831644, 'min_child_weight': 2}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:25,940] Trial 54 finished with value: 1.2456456733812908 and parameters: {'n_estimators': 216, 'max_depth': 4, 'learning_rate': 0.011785638421408543, 'subsample': 0.8844232864729843, 'colsample_bytree': 0.7229220445410389, 'gamma': 4.255353702798827, 'min_child_weight': 1}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:26,411] Trial 55 finished with value: 1.2269075615603677 and parameters: {'n_estimators': 481, 'max_depth': 3, 'learning_rate': 0.06416305206889977, 'subsample': 0.8241012917547152, 'colsample_bytree': 0.6558607457801006, 'gamma': 3.864143482313617, 'min_child_weight': 2}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:27,072] Trial 56 finished with value: 1.2439993782271033 and parameters: {'n_estimators': 286, 'max_depth': 5, 'learning_rate': 0.045754355478853016, 'subsample': 0.6689949375925305, 'colsample_bytree': 0.7382071508799234, 'gamma': 1.7344395401218042, 'min_child_weight': 4}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:27,645] Trial 57 finished with value: 1.2487814782253923 and parameters: {'n_estimators': 215, 'max_depth': 4, 'learning_rate': 0.01080212116319089, 'subsample': 0.7956431663922501, 'colsample_bytree': 0.7973396589050836, 'gamma': 4.631130566786773, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:28,157] Trial 58 finished with value: 1.2775910124669398 and parameters: {'n_estimators': 291, 'max_depth': 6, 'learning_rate': 0.10257915977123983, 'subsample': 0.9079798979935684, 'colsample_bytree': 0.8789951613478229, 'gamma': 1.4631565375419813, 'min_child_weight': 2}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:28,398] Trial 59 finished with value: 1.2228301919954572 and parameters: {'n_estimators': 124, 'max_depth': 3, 'learning_rate': 0.03218624225496849, 'subsample': 0.6851701130674426, 'colsample_bytree': 0.7734791496977003, 'gamma': 2.075538765714787, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:28,614] Trial 60 finished with value: 1.229937160202017 and parameters: {'n_estimators': 117, 'max_depth': 3, 'learning_rate': 0.05865996189134097, 'subsample': 0.6868847514510132, 'colsample_bytree': 0.6120952274077107, 'gamma': 1.9710390853413446, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:28,951] Trial 61 finished with value: 1.2219704450822184 and parameters: {'n_estimators': 167, 'max_depth': 3, 'learning_rate': 0.03214502056731649, 'subsample': 0.7184503878424799, 'colsample_bytree': 0.769296052543254, 'gamma': 2.0494038818633564, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:29,229] Trial 62 finished with value: 1.2299366652020003 and parameters: {'n_estimators': 162, 'max_depth': 3, 'learning_rate': 0.032058645173895506, 'subsample': 0.6369820813815182, 'colsample_bytree': 0.5534708392316988, 'gamma': 2.3084342602408574, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:29,506] Trial 63 finished with value: 1.2230163162606162 and parameters: {'n_estimators': 134, 'max_depth': 3, 'learning_rate': 0.03139643136021257, 'subsample': 0.718513912233297, 'colsample_bytree': 0.8105540210141227, 'gamma': 2.1151332509131264, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:29,730] Trial 64 finished with value: 1.2410643140063338 and parameters: {'n_estimators': 131, 'max_depth': 3, 'learning_rate': 0.07516933823572858, 'subsample': 0.9973034947043339, 'colsample_bytree': 0.8154571896905384, 'gamma': 2.061108773776194, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:30,025] Trial 65 finished with value: 1.2301032150213236 and parameters: {'n_estimators': 119, 'max_depth': 3, 'learning_rate': 0.034082509283224593, 'subsample': 0.7575416711738371, 'colsample_bytree': 0.8399620639808631, 'gamma': 3.2693016037116767, 'min_child_weight': 10}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:30,364] Trial 66 finished with value: 1.2232476073713665 and parameters: {'n_estimators': 153, 'max_depth': 3, 'learning_rate': 0.05041853104580436, 'subsample': 0.7415703722775739, 'colsample_bytree': 0.9062348327992417, 'gamma': 1.3934268931877307, 'min_child_weight': 9}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:30,909] Trial 67 finished with value: 1.2353385505363934 and parameters: {'n_estimators': 374, 'max_depth': 3, 'learning_rate': 0.047436100516758076, 'subsample': 0.7424458957849316, 'colsample_bytree': 0.9342809980217003, 'gamma': 2.193566979787188, 'min_child_weight': 8}. Best is trial 15 with value: 1.2187613566145867.
# [I 2025-07-26 00:47:31,176] Trial 68 finished with value: 1.2164651461684617 and parameters: {'n_estimators': 112, 'max_depth': 3, 'learning_rate': 0.054735411492865926, 'subsample': 0.7159092232209765, 'colsample_bytree': 0.9930376662969813, 'gamma': 1.960047510279586, 'min_child_weight': 10}. Best is trial 68 with value: 1.2164651461684617.
# [I 2025-07-26 00:47:31,437] Trial 69 finished with value: 1.2368107353979334 and parameters: {'n_estimators': 142, 'max_depth': 3, 'learning_rate': 0.1180055268872423, 'subsample': 0.7174952428543292, 'colsample_bytree': 0.8721684550910176, 'gamma': 2.4807538531278706, 'min_child_weight': 10}. Best is trial 68 with value: 1.2164651461684617.
# [I 2025-07-26 00:47:31,678] Trial 70 finished with value: 1.2382089135928194 and parameters: {'n_estimators': 111, 'max_depth': 3, 'learning_rate': 0.0842192671886426, 'subsample': 0.6864275759589475, 'colsample_bytree': 0.9584213932562294, 'gamma': 2.6404875201783646, 'min_child_weight': 10}. Best is trial 68 with value: 1.2164651461684617.
# [I 2025-07-26 00:47:31,954] Trial 71 finished with value: 1.2141045408972269 and parameters: {'n_estimators': 139, 'max_depth': 3, 'learning_rate': 0.05732966535829984, 'subsample': 0.7295274596534893, 'colsample_bytree': 0.9951520371209455, 'gamma': 1.908123898019241, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:32,244] Trial 72 finished with value: 1.2300876596768895 and parameters: {'n_estimators': 129, 'max_depth': 3, 'learning_rate': 0.06729636178066566, 'subsample': 0.5231683028380587, 'colsample_bytree': 0.9970682187660532, 'gamma': 1.5715393031762956, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:32,555] Trial 73 finished with value: 1.2318709349610306 and parameters: {'n_estimators': 145, 'max_depth': 3, 'learning_rate': 0.05856612251631707, 'subsample': 0.7653137105117742, 'colsample_bytree': 0.9936469153432762, 'gamma': 2.016021925191369, 'min_child_weight': 10}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:32,897] Trial 74 finished with value: 1.2187299542692902 and parameters: {'n_estimators': 106, 'max_depth': 4, 'learning_rate': 0.0401729303269582, 'subsample': 0.7227255236624961, 'colsample_bytree': 0.9681816180262659, 'gamma': 2.164069992853244, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:33,247] Trial 75 finished with value: 1.2301254042836351 and parameters: {'n_estimators': 109, 'max_depth': 4, 'learning_rate': 0.041258437947613746, 'subsample': 0.7027618224852091, 'colsample_bytree': 0.9712291873488799, 'gamma': 1.8856483199064182, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:33,827] Trial 76 finished with value: 1.2466165823904016 and parameters: {'n_estimators': 103, 'max_depth': 8, 'learning_rate': 0.05569117960601327, 'subsample': 0.7318182044267615, 'colsample_bytree': 0.9854137634708735, 'gamma': 1.2156943492251808, 'min_child_weight': 10}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:34,322] Trial 77 finished with value: 1.2273409234313586 and parameters: {'n_estimators': 165, 'max_depth': 4, 'learning_rate': 0.025620632427929557, 'subsample': 0.6729763569527047, 'colsample_bytree': 0.9453488494871161, 'gamma': 2.77505064877693, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:34,879] Trial 78 finished with value: 1.290171896242529 and parameters: {'n_estimators': 412, 'max_depth': 4, 'learning_rate': 0.1603710923585316, 'subsample': 0.6131790885296534, 'colsample_bytree': 0.9716763239015819, 'gamma': 2.4449872087372744, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:35,455] Trial 79 finished with value: 1.2490851359163468 and parameters: {'n_estimators': 178, 'max_depth': 10, 'learning_rate': 0.07016911596240855, 'subsample': 0.6466475710746721, 'colsample_bytree': 0.9703427499486873, 'gamma': 1.7309798207225064, 'min_child_weight': 10}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:35,730] Trial 80 finished with value: 1.2396040950502316 and parameters: {'n_estimators': 123, 'max_depth': 4, 'learning_rate': 0.14824634012840646, 'subsample': 0.7662812146940555, 'colsample_bytree': 0.9229602505058397, 'gamma': 2.2392437167930868, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:36,009] Trial 81 finished with value: 1.2198774983690917 and parameters: {'n_estimators': 134, 'max_depth': 3, 'learning_rate': 0.03529061910954791, 'subsample': 0.7210373980971765, 'colsample_bytree': 0.7895960470314408, 'gamma': 2.120922079014693, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:36,366] Trial 82 finished with value: 1.219888997984027 and parameters: {'n_estimators': 148, 'max_depth': 3, 'learning_rate': 0.03755943337001704, 'subsample': 0.7120723402144942, 'colsample_bytree': 0.9849743269388973, 'gamma': 1.8391219400439553, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:36,710] Trial 83 finished with value: 1.2206405054130827 and parameters: {'n_estimators': 159, 'max_depth': 3, 'learning_rate': 0.04002710553497232, 'subsample': 0.7100554240940243, 'colsample_bytree': 0.9827112167537134, 'gamma': 1.9015511335202797, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:37,059] Trial 84 finished with value: 1.2453772265382157 and parameters: {'n_estimators': 151, 'max_depth': 3, 'learning_rate': 0.015969773166557493, 'subsample': 0.6590737457805055, 'colsample_bytree': 0.9792819084112069, 'gamma': 1.8606348271893798, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:37,398] Trial 85 finished with value: 1.229274016930694 and parameters: {'n_estimators': 140, 'max_depth': 3, 'learning_rate': 0.04346095172420921, 'subsample': 0.7039612800890421, 'colsample_bytree': 0.949820483639647, 'gamma': 1.6245726806195748, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:37,823] Trial 86 finished with value: 1.2265882077270867 and parameters: {'n_estimators': 200, 'max_depth': 4, 'learning_rate': 0.09449949523019827, 'subsample': 0.7269851027683948, 'colsample_bytree': 0.9870941574082728, 'gamma': 1.501005930858567, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:38,222] Trial 87 finished with value: 1.2325507600702887 and parameters: {'n_estimators': 189, 'max_depth': 3, 'learning_rate': 0.061057331458505504, 'subsample': 0.7430554027533129, 'colsample_bytree': 0.9414254459925557, 'gamma': 1.769988287194502, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:38,535] Trial 88 finished with value: 1.2399115903904163 and parameters: {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.08502057588764175, 'subsample': 0.7070985023683819, 'colsample_bytree': 0.9608676352659213, 'gamma': 1.1239820218204257, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:38,788] Trial 89 finished with value: 1.2366359571674086 and parameters: {'n_estimators': 113, 'max_depth': 3, 'learning_rate': 0.03951157709091595, 'subsample': 0.7581566946842784, 'colsample_bytree': 0.9027565708968567, 'gamma': 1.9465153780451574, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:39,188] Trial 90 finished with value: 1.2271880365297834 and parameters: {'n_estimators': 159, 'max_depth': 4, 'learning_rate': 0.050705568418715354, 'subsample': 0.7860361555325087, 'colsample_bytree': 0.9198098772536194, 'gamma': 2.5694146552203243, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:39,591] Trial 91 finished with value: 1.2257555304404386 and parameters: {'n_estimators': 176, 'max_depth': 3, 'learning_rate': 0.026463299161126802, 'subsample': 0.7216892195322323, 'colsample_bytree': 0.9987861802252245, 'gamma': 2.352961848309515, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:39,926] Trial 92 finished with value: 1.2248278276589903 and parameters: {'n_estimators': 148, 'max_depth': 3, 'learning_rate': 0.03703150807021803, 'subsample': 0.6952972867237889, 'colsample_bytree': 0.7892578615194168, 'gamma': 2.2012574445757433, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:40,330] Trial 93 finished with value: 1.2247936038226532 and parameters: {'n_estimators': 169, 'max_depth': 3, 'learning_rate': 0.025333088854556655, 'subsample': 0.7343061713894664, 'colsample_bytree': 0.9806000608221058, 'gamma': 1.6618311784433457, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:40,679] Trial 94 finished with value: 1.2283808151384277 and parameters: {'n_estimators': 183, 'max_depth': 3, 'learning_rate': 0.01796487210187112, 'subsample': 0.713722565062969, 'colsample_bytree': 0.7569706143716181, 'gamma': 1.9336891973148818, 'min_child_weight': 10}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:41,031] Trial 95 finished with value: 1.2187620201112985 and parameters: {'n_estimators': 138, 'max_depth': 3, 'learning_rate': 0.05257891563190333, 'subsample': 0.6799576904048825, 'colsample_bytree': 0.9619478274626156, 'gamma': 1.811783233629029, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:41,570] Trial 96 finished with value: 1.2390996587907517 and parameters: {'n_estimators': 137, 'max_depth': 5, 'learning_rate': 0.05690585492047751, 'subsample': 0.6781324934271382, 'colsample_bytree': 0.9552097852192009, 'gamma': 1.3115266026325134, 'min_child_weight': 8}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:42,427] Trial 97 finished with value: 1.2751797865971057 and parameters: {'n_estimators': 356, 'max_depth': 6, 'learning_rate': 0.0709222245077325, 'subsample': 0.6616777119884408, 'colsample_bytree': 0.9356508507758151, 'gamma': 0.901945599659546, 'min_child_weight': 10}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:42,828] Trial 98 finished with value: 1.2288557487075802 and parameters: {'n_estimators': 128, 'max_depth': 4, 'learning_rate': 0.04802174089461512, 'subsample': 0.5990355504434628, 'colsample_bytree': 0.964737018778692, 'gamma': 1.7833463683808142, 'min_child_weight': 9}. Best is trial 71 with value: 1.2141045408972269.
# [I 2025-07-26 00:47:43,116] Trial 99 finished with value: 1.2819934570457718 and parameters: {'n_estimators': 110, 'max_depth': 3, 'learning_rate': 0.014333932904057649, 'subsample': 0.5681967060214317, 'colsample_bytree': 0.9872998375020883, 'gamma': 1.524686414878601, 'min_child_weight': 5}. Best is trial 71 with value: 1.2141045408972269.
#
# Лучшие параметры:
# {'n_estimators': 139, 'max_depth': 3, 'learning_rate': 0.05732966535829984, 'subsample': 0.7295274596534893, 'colsample_bytree': 0.9951520371209455, 'gamma': 1.908123898019241, 'min_child_weight': 9}
#
# Финальные метрики:
# RMSE: 1.0935
# MAE: 0.8467
# R2: 0.5678
#
# Сравнение с предыдущей лучшей версией этой модели (до Optuna):
# RMSE было: 1.0957 → стало: 1.0935
# Улучшение: 0.0022
# R2 было: 0.5661 → стало: 0.5678
# Улучшение: -0.0017

# %% [markdown]
# Оптимизация с помощью Optuna позволила незначительно, но стабильно улучшить все ключевые метрики. Хотя прирост невелик, он подтверждает, что выбранные параметры находятся вблизи оптимума. Модель XGBoost окончательно закрепила своё лидерство.

# %%
target_model = best_model_name

# 1. Получаем без подбора
base_row = all_results[(all_results['Model'] == target_model) & (all_results['Hyperparametres'] == False)].sort_values('RMSE').iloc[0]

# 2. С подбором (RandomizedSearch)
random_row = all_results[(all_results['Model'] == target_model) & (all_results['Hyperparametres'] == True)].sort_values('RMSE').iloc[0]

# 3. Финальные метрики Optuna
optuna_metrics = {
    'RMSE': final_rmse,
    'MAE': final_mae,
    'R2': final_r2
}

# 4. Собираем всё в DataFrame
progress = pd.DataFrame({
    'Этап': ['Без подбора', 'RandomizedSearch', 'Optuna'],
    'RMSE': [base_row['RMSE'], random_row['RMSE'], optuna_metrics['RMSE']],
    'MAE':  [base_row['MAE'],  random_row['MAE'],  optuna_metrics['MAE']],
    'R2':   [base_row['R2'],   random_row['R2'],   optuna_metrics['R2']],
})

# 5. Строим график
for metric in ['RMSE', 'MAE', 'R2']:
    plt.figure(figsize=(8, 5))
    plt.plot(progress['Этап'], progress[metric], marker='o', linewidth=2)
    plt.title(f'Изменение метрики {metric} по этапам — {target_model}')
    plt.xlabel('Этап')
    plt.ylabel(metric)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# На основании полученных результатов, оптимальным выбором модели для задачи предсказания IC50 является XGBoost с подбором гиперпараметров, выполненным с помощью Optuna. Модель показала наилучшие значения по метрикам RMSE и R2, а её финальные настройки обеспечили стабильное улучшение качества предсказаний.
